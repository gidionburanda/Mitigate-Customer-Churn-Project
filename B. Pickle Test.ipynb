# %%
from google.colab import drive
drive.mount('/content/drive')
data=pd.read_csv('/content/drive/MyDrive/Data sudah merge dan cleaning/fix_nooutliers_balance.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Split train-test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
import pickle
my_dict = pickle.load(open('/content/drive/MyDrive/churn_prediction_italy.pkl', 'rb'))
my_dict
# Out:
# XGBClassifier(colsample_bytree=0.6676525776632632, gamma=1.8828509176885833,
#               max_depth=14, min_child_weight=8.0, missing=nan, reg_alpha=98.0,
#               reg_lambda=0.5793448934763148)

# %%
my_dict.fit(X_train,y_train)
pred = my_dict.predict(X_test)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, my_dict.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       587
#            1       0.95      1.00      0.98     12244
#
#     accuracy                           0.95     12831
#    macro avg       0.48      0.50      0.49     12831
# weighted avg       0.91      0.95      0.93     12831
